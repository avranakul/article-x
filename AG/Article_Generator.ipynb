# %%
# !nvidia-smi
# Out:
# Fri Oct 22 13:36:10 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   70C    P8    32W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install transformers
# Out:
# ...
#      |████████████████████████████████| 2.9 MB 2.7 MB/s
# ...
#      |████████████████████████████████| 596 kB 64.7 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 42.8 MB/s
# ...
#      |████████████████████████████████| 56 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 895 kB 70.9 MB/s
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2-large') 
model = GPT2LMHeadModel.from_pretrained('gpt2-large' , 
pad_token_id = tokenizer.eos_token_id)
# Out:
# Downloading:   0%|          | 0.00/0.99M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.29M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/666 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/3.02G [00:00<?, ?B/s]

# %%
tokenizer.decode(tokenizer.eos_token_id)
# Out:
# '<|endoftext|>'

# %%
sentence ="What is lithium air batteries ?" #content you wanna generate
input_ids = tokenizer.encode(sentence, return_tensors= "pt")

# %%
input_ids
# Out:
# tensor([[ 2061,   318, 28444,  1633, 13591,  5633]])

# %%
print(tokenizer.decode(input_ids[0]))
print(tokenizer.decode(input_ids[0][0]))
print(tokenizer.decode(input_ids[0][1]))
print(tokenizer.decode(input_ids[0][2]))
print(tokenizer.decode(input_ids[0][3]))
print(tokenizer.decode(input_ids[0][4]))
print(tokenizer.decode(input_ids[0][5]))
# print(tokenizer.decode(input_ids[0][6]))
# print(tokenizer.decode(input_ids[0][7]))
# print(tokenizer.decode(input_ids[0][8]))
# print(tokenizer.decode(input_ids[0][9]))
# print(tokenizer.decode(input_ids[0][10]))
# print(tokenizer.decode(input_ids[0][11]))
# print(tokenizer.decode(input_ids[0][12]))
# print(tokenizer.decode(input_ids[0][13]))
# print(tokenizer.decode(input_ids[0][14]))
# Out:
# What is lithium air batteries?
# What
#  is
#  lithium
#  air
#  batteries
# ?

# %%
output = model.generate(input_ids, max_length = 5000, num_beams=2, no_repeat_ngram_size= 2, early_stopping= True)

# %%
len(output[0])
# Out:
# 126

# %%
print(tokenizer.decode(output[0], skip_special_tokens= True))
# Out:
# What is lithium air batteries?
#
# Lithium-air batteries are a type of rechargeable battery that uses lithium metal as the anode. The lithium is stored in the cathode, which is the positive electrode of the battery. When the voltage is high enough, the lithium ions are able to flow through the electrolyte and into the negative electrode, where they can be stored. This process is called electrolysis, and it is used to store energy in batteries. Lithium metal is also used as a cathodic material in lithium-ion batteries, but it does not have the same properties as lithium.
# .
